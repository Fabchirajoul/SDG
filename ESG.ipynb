# %% [markdown]
# <a href="https://colab.research.google.com/github/Fabchirajoul/SDG/blob/main/ESG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)

# %%
pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.18.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
pip install accelerate -U
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.28.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.4.99)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %%
import random

# For our testing dataset

def random_sample_testing(input_file, output_file, sample_percentage=0.2):
    with open(input_file, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    # Extract header and content separately
    header = lines[0]
    content = lines[1:]

    num_lines = len(content)
    sample_size = int(num_lines * sample_percentage)

    sampled_lines = random.sample(content, sample_size)

    # Add the "TEXT" header back at the beginning
    sampled_lines = [header] + sampled_lines

    with open(output_file, 'w', encoding='utf-8') as file:
        file.writelines(sampled_lines)

# Example usage
input_document = "/content/governance_metric_proper.csv"
output_sample = "/content/training_dataset_governance.csv"
random_sample_testing(input_document, output_sample, sample_percentage=0.9)



# For our training dataset

def random_sample_testing(input_file, output_file, sample_percentage=0.1):
    with open(input_file, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    # Extract header and content separately
    header = lines[0]
    content = lines[1:]

    num_lines = len(content)
    sample_size = int(num_lines * sample_percentage)

    sampled_lines = random.sample(content, sample_size)

    # Add the "TEXT" header back at the beginning
    sampled_lines = [header] + sampled_lines

    with open(output_file, 'w', encoding='utf-8') as file:
        file.writelines(sampled_lines)

# Example usage
input_document = "/content/governance_metric_proper.csv"
output_sample = "/content/evaluating_dataset_governance.csv"
random_sample_testing(input_document, output_sample, sample_percentage=0.2)

# %%
import random
from transformers import Trainer, TrainingArguments, AutoTokenizer, AutoModelForSequenceClassification, AdamW, get_scheduler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from transformers import DataCollatorWithPadding
from datasets import load_dataset
import torch

# %%
data_files = {"train": "/content/training_dataset_governance.csv",
              "validation": "/content/evaluating_dataset_governance.csv"}
df_governance = load_dataset("csv", data_files=data_files)
df_governance
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['Company', 'Indicator', 'Context', 'Metric', 'Metric Unit', 'Latest Year'],
#         num_rows: 1624
#     })
#     validation: Dataset({
#         features: ['Company', 'Indicator', 'Context', 'Metric', 'Metric Unit', 'Latest Year'],
#         num_rows: 361
#     })
# })

# %%
governance_keywords = [
"Legal Proceeding and Law violations",
"Economic Crime",
"Responsible Investment and Greenwashing",
"Supply Chain",
"Economic / Governance",
"Corporate Governance",
"Values and Ethics",
"Risk Management and Internal control",
"Strategy Implimentation",
"Disclosure"

]

# %%
# def label_data(row):
#     for keyword in governance_keywords:
#         if keyword in row["Indicator"].lower():
#             return {"label": 1, "Metric": row["Metric"], "Metric Unit": row["Metric Unit"]}
#     return {"label": 0, "Metric": None, "Metric Unit": None}

def label_data(row):
    for keyword in governance_keywords:
        if keyword in row["Indicator"].lower():
            return {"input": row, "label": 1, "Metric": row["Metric"], "Metric Unit": row["Metric Unit"]}
    return {"input": row, "label": 0, "Metric": None, "Metric Unit": None}

# %%
# Apply label_data function to each row in the dataset
labeled_data = df_governance.map(label_data)
labeled_data
# Out:
# Map:   0%|          | 0/1624 [00:00<?, ? examples/s]
# Map:   0%|          | 0/361 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['Company', 'Indicator', 'Context', 'Metric', 'Metric Unit', 'Latest Year', 'input', 'label'],
#         num_rows: 1624
#     })
#     validation: Dataset({
#         features: ['Company', 'Indicator', 'Context', 'Metric', 'Metric Unit', 'Latest Year', 'input', 'label'],
#         num_rows: 361
#     })
# })

# %%
# Step 3: Tokenize the data
tokenizer = AutoTokenizer.from_pretrained("ESGBERT/GovRoBERTa-governance")
def tokenize_data(row):
    inputs = tokenizer(
        row["Company"],
        row["Indicator"],
        row["Context"],
        str(row["Latest Year"]),
        return_tensors="pt",
        padding=True,
        max_length=512,
        truncation=True  # Add truncation
    )

    # Flatten the input tensor
    inputs = {key: value.squeeze(0) for key, value in inputs.items()}

    return inputs


tokenized_data = labeled_data.map(tokenize_data)
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
tokenized_data.set_format("torch")
tokenized_data.column_names
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Map:   0%|          | 0/1624 [00:00<?, ? examples/s]
# Map:   0%|          | 0/361 [00:00<?, ? examples/s]
# {'train': ['Company',
#   'Indicator',
#   'Context',
#   'Metric',
#   'Metric Unit',
#   'Latest Year',
#   'input',
#   'label',
#   'input_ids',
#   'attention_mask',
#   'labels'],
#  'validation': ['Company',
#   'Indicator',
#   'Context',
#   'Metric',
#   'Metric Unit',
#   'Latest Year',
#   'input',
#   'label',
#   'input_ids',
#   'attention_mask',
#   'labels']}

# %%
tokenized_data.column_names
# Out:
# {'train': ['Company',
#   'Indicator',
#   'Context',
#   'Metric',
#   'Metric Unit',
#   'Latest Year',
#   'input',
#   'label',
#   'input_ids',
#   'attention_mask',
#   'labels'],
#  'validation': ['Company',
#   'Indicator',
#   'Context',
#   'Metric',
#   'Metric Unit',
#   'Latest Year',
#   'input',
#   'label',
#   'input_ids',
#   'attention_mask',
#   'labels']}

# %%
tokenized_data.set_format("torch")

# %%
# Step 4: Define the model
model_governance = AutoModelForSequenceClassification.from_pretrained("ESGBERT/GovRoBERTa-governance")

# %%
from torch.utils.data import DataLoader


# Check the expected input size from the model's configuration
lr=5e-5
num_epochs = 1
batch_size = 1
optimizer = torch.optim.AdamW(model_governance.parameters(), lr=lr)

# %%
# Define the scheduler
num_training_steps = len(tokenized_data["train"]) * num_epochs
lr_scheduler = get_scheduler(
    "linear",
    optimizer=optimizer,
    num_warmup_steps=0,
    num_training_steps=num_training_steps
)

# %%
device_governance = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model_governance.to(device_governance)
print("========================================================================================")
print("Our available device which our model is going to be trained on is: \n\n", device_governance)
print("========================================================================================")
# Making sure our model is ready to be  trained
print("Our Training Model architecture is: \n\n", model_governance.train())
print("========================================================================================")
# Out:
# ========================================================================================
# Our available device which our model is going to be trained on is:
#
#  cuda
# ========================================================================================
# Our Training Model architecture is:
#
#  RobertaForSequenceClassification(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 768, padding_idx=2)
#       (position_embeddings): Embedding(514, 768, padding_idx=2)
#       (token_type_embeddings): Embedding(1, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): RobertaSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): RobertaClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#   )
# )
# ========================================================================================

# %%
# Step 5: Fine-tune the model
training_args = TrainingArguments(
    output_dir="Governance",
    overwrite_output_dir=True,
    num_train_epochs=num_epochs,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    learning_rate=lr,
    weight_decay=0.01,
    logging_dir="Governance_Model_Saved",
    logging_steps=100,
    save_steps=500,
    evaluation_strategy="epoch",
    save_strategy= "epoch",
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",  # Adjust metric as needed for your task
)

# %%
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)

    accuracy = accuracy_score(labels, preds)
    # precision = precision_score(labels, preds, average='binary', zero_division=)
    # recall = recall_score(labels, preds, average='binary', zero_division='warn')
    # f1 = f1_score(labels, preds, average='binary', zero_division='warn')
    precision = precision_score(labels.flatten(), preds.flatten(), average='macro', zero_division=0)
    f1 = f1_score(labels.flatten(), preds.flatten(), average='macro')
    return {"accuracy": accuracy.item(), "precision": precision, "f1": f1}

    return {
        'eval_accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1
    }


    print("Type of predictions:", (pred.predictions))
    print("Predictions:", pred.predictions)

# %%
# Define Trainer
print("Before creating Trainer instance")
trainer = Trainer(
    model=model_governance,
    args=training_args,
    train_dataset=tokenized_data["train"],
    eval_dataset=tokenized_data["validation"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
print("Trainer instance created")
# Out:
# Before creating Trainer instance
# Trainer instance created
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(

# %%
# Before training
print("Before training")
for batch in trainer.get_train_dataloader():
    print("Shape of inputs:", batch['input_ids'].shape)  # Print shape of input_ids
    break  # Only print the shape of the first batch
# Out:
# Before training
# Shape of inputs: torch.Size([1, 10])

# %%
# Train the model
print("Before training")
trainer.train()
print("Training completed")
# Out:
# Before training
#     <div>
#
#       <progress value='1624' max='1624' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1624/1624 02:16, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#       <td>1.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Checkpoint destination directory Governance/checkpoint-1624 already exists and is non-empty. Saving will proceed but saved results may be invalid.
# Training completed

# %%
# Load the validation dataset
# validation_dataset = load_dataset("csv", data_files="/content/evaluating_dataset_governance.csv")["train"]
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
# Load the validation dataset
validation_data_files = {"validation": "/content/evaluating_dataset_governance.csv"}
validation_dataset = load_dataset("csv", data_files=validation_data_files)["validation"]
# Out:
# Generating validation split: 0 examples [00:00, ? examples/s]

# %%
def evaluate_batch(batch):
    batch = {key: [value] if not isinstance(value, list) else value for key, value in batch.items()}  # Ensure batch has consistent format

    # Concatenate input fields into single sequences or text pairs
    inputs = [f"{company} {indicator} {context} {latest_year}" for company, indicator, context, latest_year in zip(batch["Company"], batch["Indicator"], batch["Context"], batch["Latest Year"])]

    inputs = tokenizer(
        inputs,
        return_tensors="pt",
        padding=True,
        truncation=True
    )
    inputs = {key: value.to(device_governance) for key, value in inputs.items()}  # Move inputs to the same device as the model
    with torch.no_grad():  # Ensure gradients are not calculated during inference
        outputs = model_governance(**inputs)
    predicted_labels = torch.sigmoid(outputs.logits) > 0.5  # Apply threshold for binary classification
    predicted_metrics = []
    for idx, predicted_label in enumerate(predicted_labels):
        # Check each element of predicted_label tensor individually
        if predicted_label[0].item():  # Convert tensor to boolean value
            predicted_metrics.append({"Predicted Metric": batch["Metric"][idx], "Predicted Metric unit": batch["Metric Unit"][idx]})
        else:
            predicted_metrics.append({"Predicted Metric": None, "Predicted Metric unit": None})
    return predicted_metrics

# %%
predicted_results = []
for batch in validation_dataset:
    batch_results = evaluate_batch(batch)
    predicted_results.extend(batch_results)

# Print or process the predicted results as needed
for result in predicted_results:
    print(result)
# Out:
# {'Predicted Metric': 84.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 1.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 4.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 7.6, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 1.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 8.61, 'Predicted Metric unit': 'Rand'}
# {'Predicted Metric': 300.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 30.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 2.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 107.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 36.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 30.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 18.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 8.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 70.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 14.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 78.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 40.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 646.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 2.2, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 2.8, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 200.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 22.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 50.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 20.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 116.5, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 75.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 93.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 2019.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 0.29, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 2023.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 1.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 7.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 26.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 50.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 686.2, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 9.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 356.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 82.7, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 30.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 2018.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 78.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 60.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 97.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 2.52, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 2023.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 500.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 12.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 445.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 15.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 50.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 2022.0, 'Predicted Metric unit': 'EMPLOYEES'}
# {'Predicted Metric': 280.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 30.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 2022.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 9.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 4.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 4.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 4.0, 'Predicted Metric unit': 'Level'}
# {'Predicted Metric': 0.8, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 25.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 286.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 359.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 6.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 260.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 6.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 867.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'Level'}
# {'Predicted Metric': 30.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 1.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 233.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 22.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 2.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 89.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 503.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 64.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 100.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 0.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 88.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 30.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 170.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 67.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 89.08, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 10.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 50.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 11.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 29.4, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 55.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 41.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 670.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 1.0, 'Predicted Metric unit': 'Level'}
# {'Predicted Metric': 8.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 49.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 7.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 47.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 0.64, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 49.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 4.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 625.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 585.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 4.5, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 7.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 54.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 50.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 30.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 9.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 871.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 10.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 126.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 7.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 92.5, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 30.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 39.0, 'Predicted Metric unit': 'EMPLOYEES'}
# {'Predicted Metric': 168.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 863.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 27.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 500.0, 'Predicted Metric unit': 'days'}
# {'Predicted Metric': 14.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 359.0, 'Predicted Metric unit': 'hours'}
# {'Predicted Metric': 3.8, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 53.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 7.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 1.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 35.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 50.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 91.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 48.0, 'Predicted Metric unit': 'hours'}
# {'Predicted Metric': 21.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 521.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 20.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 42.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 2.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 205.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 843.0, 'Predicted Metric unit': 'EMPLOYEES'}
# {'Predicted Metric': 27.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 70.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 711.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 70.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 1.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 6.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 59.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 56.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 37.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 250.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 1.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 10.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 9.0, 'Predicted Metric unit': 'BILLION'}
# {'Predicted Metric': 8.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 50.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 30.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 25.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 86.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 297.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 251.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 1.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 1.2, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 60.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 67.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 40.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 786.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 359.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 25.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 30.0, 'Predicted Metric unit': 'hours'}
# {'Predicted Metric': 18.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 39.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 802.0, 'Predicted Metric unit': 'EMPLOYEES'}
# {'Predicted Metric': 39.24, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 27.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 5050.39, 'Predicted Metric unit': 'hours'}
# {'Predicted Metric': 60.6, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 25.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 4.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 9.6, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 110.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 48.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 447.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 35.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 30.0, 'Predicted Metric unit': 'days'}
# {'Predicted Metric': 23.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 30.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 12.58, 'Predicted Metric unit': 'days'}
# {'Predicted Metric': 30.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 100.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 6.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 3.2, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 2.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 1.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 10.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 6.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 50.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 20.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 18.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 1.6, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 819.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 2.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 850.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 6.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 81.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 40.0, 'Predicted Metric unit': 'hours'}
# {'Predicted Metric': 9.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 60.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 2.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 9.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 58.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 4.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 10.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 36.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 64.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 252.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 31.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 1.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 40.0, 'Predicted Metric unit': 'days'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 4.0, 'Predicted Metric unit': 'Level'}
# {'Predicted Metric': 2.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 15.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 588.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 0.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 100.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 7.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 27.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 10.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 4.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 132.0, 'Predicted Metric unit': 'MILLION'}
# {'Predicted Metric': 10.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 17.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 4.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 43.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 25.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 25.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 117.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 35.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 66.8, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 0.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 9.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 30.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 802.0, 'Predicted Metric unit': 'EMPLOYEES'}
# {'Predicted Metric': 2.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 93.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 543.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 1.0, 'Predicted Metric unit': 'Level'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 89.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 22.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 33.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 399.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 200.0, 'Predicted Metric unit': 'hours'}
# {'Predicted Metric': 7.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 21.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 749.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 2023.0, 'Predicted Metric unit': 'Score'}
# {'Predicted Metric': 2023.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 14.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 32.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 70.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 592.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 33.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 63.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 34.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 9.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 959.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 12.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 18.87, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 37.2, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 7.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 748.0, 'Predicted Metric unit': 'Rand'}
# {'Predicted Metric': 2.2, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 53.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 426.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 20.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 6.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 910.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 49.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 33.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 20.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 4.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 1.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 14138643.0, 'Predicted Metric unit': 'EMPLOYEES'}
# {'Predicted Metric': 845.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 6.0, 'Predicted Metric unit': 'MILLION'}
# {'Predicted Metric': 2.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 6.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 6.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 59.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 85.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 25.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 47.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 4.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 207.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 96.86, 'Predicted Metric unit': 'Level'}
# {'Predicted Metric': 50.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 8.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 2.6, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 13.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 102.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 69.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 653.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 91.0, 'Predicted Metric unit': 'hours'}
# {'Predicted Metric': 40.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 0.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 2.3, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 7.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 206.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'billion'}
# {'Predicted Metric': 10.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 7.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 71.0, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 10.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 50.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 2.0, 'Predicted Metric unit': 'No'}
# {'Predicted Metric': 40.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 36.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 97.0, 'Predicted Metric unit': '%'}
# {'Predicted Metric': 46.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 0.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 787.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 240.0, 'Predicted Metric unit': 'Number'}
# {'Predicted Metric': 48.0, 'Predicted Metric unit': 'hours'}
# {'Predicted Metric': 7.2, 'Predicted Metric unit': 'million'}
# {'Predicted Metric': 3.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 40.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 5.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 6.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 20.0, 'Predicted Metric unit': 'years'}
# {'Predicted Metric': 0.0, 'Predicted Metric unit': 'employees'}
# {'Predicted Metric': 7.0, 'Predicted Metric unit': 'Employees'}
# {'Predicted Metric': 4.0, 'Predicted Metric unit': 'billion'}
