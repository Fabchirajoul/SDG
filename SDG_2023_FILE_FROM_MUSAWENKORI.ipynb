# %% [markdown]
# <a href="https://colab.research.google.com/github/Fabchirajoul/SDG/blob/main/SDG_2023_FILE_FROM_MUSAWENKORI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing the neccessary Libraries

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from IPython.display import display, Markdown
import torch
import plotly.express as px
import pandas as pd
from nltk.tokenize import sent_tokenize
import nltk
import regex as re

# Download NLTK tokenizer data
nltk.download('punkt')

import seaborn as sns
import numpy as np
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Invoking the SDG Pre-trained model

# %%
# Model name or path to model
checkpoint = "sadickam/sdg-classification-bert"
# model = AutoModelForSequenceClassification.from_pretrained(checkpoint)
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %% [markdown]
# ## Load the model

# %%
def load_model():
    return AutoModelForSequenceClassification.from_pretrained(checkpoint)

# %% [markdown]
# ## Load the SDG Text File

# %%
# LOADING COMPANY FILE 1

file_path = "/content/Adani_combined_text.txt"


# Load the content of the file
with open(file_path, "r") as file:
    text_content = file.read()


# # LOADING COMPANY FILE 2

file_path2 = "/content/Airtel_combined_text.txt"


# Load the content of the file
with open(file_path2, "r") as file2:
    text_content2 = file2.read()


# # LOADING COMPANY FILE 3

file_path3 = "/content/Ambuja Cement_combined_text.txt"


# Load the content of the file
with open(file_path3, "r") as file3:
    text_content3 = file3.read()


# # LOADING COMPANY FILE 4

file_path4 = "/content/Asian Paints_combined_text.txt"
# Load the content of the file
with open(file_path4, "r") as file4:
    text_content4 = file4.read()

# # LOADING COMPANY FILE 5

file_path5 = "/content/Aurobindo Pharma Limited_combined_text.txt"
# Load the content of the file
with open(file_path5, "r") as file5:
    text_content5 = file5.read()

# # LOADING COMPANY FILE 6

file_path6 = "/content/Axis Bank_combined_text.txt"
# Load the content of the file
with open(file_path6, "r") as file6:
    text_content6 = file6.read()

# # LOADING COMPANY FILE 7

file_path7 = "/content/Bajaj Auto_combined_text.txt"
# Load the content of the file
with open(file_path7, "r") as file7:
    text_content7 = file7.read()

# # LOADING COMPANY FILE 8

file_path8 = "/content/Bajaj Finance_combined_text.txt"
# Load the content of the file
with open(file_path8, "r") as file8:
    text_content8 = file8.read()


# # LOADING COMPANY FILE 9

file_path9 = "/content/BOSCH_combined_text.txt"
# Load the content of the file
with open(file_path9, "r") as file9:
    text_content9 = file9.read()

# # LOADING COMPANY FILE 10

file_path10 = "/content/BP_combined_text.txt"
# Load the content of the file
with open(file_path10, "r") as file10:
    text_content10 = file10.read()

# # LOADING COMPANY FILE 11

file_path11 = "/content/Cipla_combined_text.txt"
# Load the content of the file
with open(file_path11, "r") as file11:
    text_content11 = file11.read()


# # LOADING COMPANY FILE 12

file_path12 = "/content/Coal India Limited_combined_text.txt"
# Load the content of the file
with open(file_path12, "r") as file12:
    text_content12 = file12.read()


# # LOADING COMPANY FILE 13

file_path13 = "/content/Dr. Reddy's_combined_text.txt"
# Load the content of the file
with open(file_path13, "r") as file13:
    text_content13 = file13.read()

# # LOADING COMPANY FILE 14

file_path14 = "/content/Eicher_combined_text.txt"
# Load the content of the file
with open(file_path14, "r") as file14:
    text_content14 = file14.read()


# # LOADING COMPANY FILE 15

file_path15 = "/content/GAIL_combined_text.txt"
# Load the content of the file
with open(file_path15, "r") as file15:
    text_content15 = file15.read()

# # LOADING COMPANY FILE 16

file_path16 = "/content/HCL Technologies_combined_text.txt"


# Load the content of the file
with open(file_path16, "r") as file16:
    text_content16 = file16.read()


# # LOADING COMPANY FILE 17

file_path17 = "/content/HDFC Bank_combined_text.txt"


# Load the content of the file
with open(file_path17, "r") as file17:
    text_content17 = file17.read()


# # LOADING COMPANY FILE 18

file_path18 = "/content/HDFC Ltd_combined_text.txt"


# Load the content of the file
with open(file_path18, "r") as file18:
    text_content18 = file18.read()


# # LOADING COMPANY FILE 19

file_path19 = "/content/Hero MotoCorp Limited_combined_text.txt"
# Load the content of the file
with open(file_path19, "r") as file19:
    text_content19 = file19.read()

# # LOADING COMPANY FILE 20

file_path20 = "/content/Hindalco_combined_text.txt"
# Load the content of the file
with open(file_path20, "r") as file20:
    text_content20 = file20.read()

# # LOADING COMPANY FILE 21

file_path21 = "/content/HPCL_combined_text.txt"
# Load the content of the file
with open(file_path21, "r") as file21:
    text_content21 = file21.read()

# # LOADING COMPANY FILE 22

file_path22 = "/content/HUL_combined_text.txt"
# Load the content of the file
with open(file_path22, "r") as file22:
    text_content22 = file22.read()

# # LOADING COMPANY FILE 23

file_path23 = "/content/ICICI Bank_combined_text.txt"
# Load the content of the file
with open(file_path23, "r") as file23:
    text_content23 = file23.read()


# # LOADING COMPANY FILE 24

file_path24 = "/content/Indiabulls Housing Finance Limited_combined_text.txt"
# Load the content of the file
with open(file_path24, "r") as file24:
    text_content24 = file24.read()

# # LOADING COMPANY FILE 25

file_path25 = "/content/IndianOil_combined_text.txt"
# Load the content of the file
with open(file_path25, "r") as file25:
    text_content25 = file25.read()

# # LOADING COMPANY FILE 26

file_path26 = "/content/IndusInd Bank_combined_text.txt"
# Load the content of the file
with open(file_path26, "r") as file26:
    text_content26 = file26.read()

# # LOADING COMPANY FILE 27

file_path27 = "/content/Infosys_combined_text.txt"
# Load the content of the file
with open(file_path27, "r") as file27:
    text_content27 = file27.read()


# # LOADING COMPANY FILE 28

file_path28 = "/content/ITC Limited_combined_text.txt"
# Load the content of the file
with open(file_path28, "r") as file28:
    text_content28 = file28.read()


# # LOADING COMPANY FILE 29

file_path29 = "/content/Kotak_combined_text.txt"
# Load the content of the file
with open(file_path29, "r") as file29:
    text_content29 = file29.read()

# # LOADING COMPANY FILE 30

file_path30 = "/content/Larsen & Toubro_combined_text.txt"
# Load the content of the file
with open(file_path30, "r") as file30:
    text_content30 = file30.read()


# # LOADING COMPANY FILE 31

file_path31 = "/content/Lupin_combined_text.txt"
# Load the content of the file
with open(file_path31, "r") as file31:
    text_content31 = file31.read()

# # LOADING COMPANY FILE 32

file_path32 = "/content/Mahindra & Mahindra Limited_combined_text.txt"
# Load the content of the file
with open(file_path32, "r") as file32:
    text_content32 = file32.read()

# # LOADING COMPANY FILE 33

file_path33 = "/content/Maruti Suzuki_combined_text.txt"


# Load the content of the file
with open(file_path33, "r") as file33:
    text_content33 = file33.read()


# # LOADING COMPANY FILE 34

file_path34 = "/content/NTPC_combined_text.txt"


# Load the content of the file
with open(file_path34, "r") as file34:
    text_content34 = file34.read()


# # LOADING COMPANY FILE 35

file_path35 = "/content/ONGC_combined_text.txt"


# Load the content of the file
with open(file_path35, "r") as file35:
    text_content35 = file35.read()


# # LOADING COMPANY FILE 36

file_path36 = "/content/Power Grid_combined_text.txt"
# Load the content of the file
with open(file_path36, "r") as file36:
    text_content36 = file36.read()

# LOADING COMPANY FILE 37

file_path37 = "/content/Reliance Industries Limited_combined_text.txt"
# Load the content of the file
with open(file_path37, "r") as file37:
    text_content37 = file37.read()

# LOADING COMPANY FILE 38

file_path38 = "/content/SBI_combined_text.txt"
# Load the content of the file
with open(file_path38, "r") as file38:
    text_content38 = file38.read()

# LOADING COMPANY FILE 39

file_path39 = "/content/SunPharma_combined_text.txt"
# Load the content of the file
with open(file_path39, "r") as file39:
    text_content39 = file39.read()

# LOADING COMPANY FILE 40

file_path40 = "/content/TATA Motors_combined_text.txt"
# Load the content of the file
with open(file_path40, "r") as file40:
    text_content40 = file40.read()


# LOADING COMPANY FILE 41

file_path41 = "/content/TATA Steel_combined_text.txt"
# Load the content of the file
with open(file_path41, "r") as file41:
    text_content41 = file41.read()

# LOADING COMPANY FILE 42

file_path42 = "/content/TCS_combined_text.txt"
# Load the content of the file
with open(file_path42, "r") as file42:
    text_content42 = file42.read()

# LOADING COMPANY FILE 43

file_path43 = "/content/Tech Mahindra_combined_text.txt"
# Load the content of the file
with open(file_path43, "r") as file43:
    text_content43 = file43.read()


# LOADING COMPANY FILE 44

file_path44 = "/content/Ultra Tech_combined_text.txt"
# Load the content of the file
with open(file_path44, "r") as file44:
    text_content44 = file44.read()


# LOADING COMPANY FILE 45

file_path45 = "/content/UPL Limited_combined_text.txt"
# Load the content of the file
with open(file_path45, "r") as file45:
    text_content45 = file45.read()

# LOADING COMPANY FILE 46

file_path46 = "/content/Vedanta_combined_text.txt"
# Load the content of the file
with open(file_path46, "r") as file46:
    text_content46 = file46.read()


# LOADING COMPANY FILE 47

file_path47 = "/content/WIPRO_combined_text.txt"
# Load the content of the file
with open(file_path47, "r") as file47:
    text_content47 = file47.read()

# LOADING COMPANY FILE 48

file_path48 = "/content/YES Bank_combined_text.txt"
# Load the content of the file
with open(file_path48, "r") as file48:
    text_content48 = file48.read()

# LOADING COMPANY FILE 49

file_path49 = "/content/Zee_combined_text.txt"
# Load the content of the file
with open(file_path49, "r") as file49:
    text_content49 = file49.read()

# %% [markdown]
# ## Load the Tokenizer

# %%
def load_tokenizer():
    tokenizer = AutoTokenizer.from_pretrained(checkpoint)
    return tokenizer

# %% [markdown]
# ## Passing the Text file to the tokenizer

# %%
# tokenize pre-processed 1
tokenizer_ = load_tokenizer()
tokenized_text = tokenizer_(text_content[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 2

# Truncating to 512 because the SDG bert model for sequence classification takes just 512. I still need to research on the bert model that takes the eentire length of the token
tokenizer_2 = load_tokenizer()
tokenized_text2 = tokenizer_2(text_content2[:512], return_tensors="pt", truncation=True)


# # tokenize pre-processed 3

tokenizer_3 = load_tokenizer()
tokenized_text3 = tokenizer_3(text_content3[:512], return_tensors="pt", truncation=True)

# tokenize pre-processed 4

tokenizer_4 = load_tokenizer()
tokenized_text4 = tokenizer_4(text_content4[:512], return_tensors="pt", truncation=True)




# tokenize pre-processed5

tokenizer_5 = load_tokenizer()
tokenized_text5 = tokenizer_5(text_content5[:512], return_tensors="pt", truncation=True)



# tokenize pre-processed 6

tokenizer_6 = load_tokenizer()
tokenized_text6 = tokenizer_6(text_content6[:512], return_tensors="pt", truncation=True)




# tokenize pre-processed 7

tokenizer_7 = load_tokenizer()
tokenized_text7 = tokenizer_7(text_content7[:512], return_tensors="pt", truncation=True)



# tokenize pre-processed 8

tokenizer_8 = load_tokenizer()
tokenized_text8 = tokenizer_8(text_content8[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 9

tokenizer_9 = load_tokenizer()
tokenized_text9 = tokenizer_9(text_content9[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 10

tokenizer_10 = load_tokenizer()
tokenized_text10 = tokenizer_10(text_content10[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 11

tokenizer_11 = load_tokenizer()
tokenized_text11 = tokenizer_11(text_content11[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 12

tokenizer_12 = load_tokenizer()
tokenized_text12 = tokenizer_12(text_content12[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 13

tokenizer_13 = load_tokenizer()
tokenized_text13 = tokenizer_13(text_content13[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 14

tokenizer_14 = load_tokenizer()
tokenized_text14 = tokenizer_14(text_content14[:512], return_tensors="pt", truncation=True)



# tokenize pre-processed 15

tokenizer_15 = load_tokenizer()
tokenized_text15 = tokenizer_15(text_content15[:512], return_tensors="pt", truncation=True)



# tokenize pre-processed 16

tokenizer_16 = load_tokenizer()
tokenized_text16 = tokenizer_16(text_content16[:512], return_tensors="pt", truncation=True)



# tokenize pre-processed 17
tokenizer_17 = load_tokenizer()
tokenized_text17 = tokenizer_(text_content17[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 18

# Truncating to 512 because the SDG bert model for sequence classification takes just 512. I still need to research on the bert model that takes the eentire length of the token
tokenizer_18 = load_tokenizer()
tokenized_text18 = tokenizer_18(text_content18[:512], return_tensors="pt", truncation=True)




# tokenize pre-processed 19

tokenizer_19 = load_tokenizer()
tokenized_text19 = tokenizer_19(text_content19[:512], return_tensors="pt", truncation=True)




# tokenize pre-processed 20

tokenizer_20 = load_tokenizer()
tokenized_text20 = tokenizer_20(text_content20[:512], return_tensors="pt", truncation=True)



# tokenize pre-processed 21

tokenizer_21 = load_tokenizer()
tokenized_text21 = tokenizer_21(text_content21[:512], return_tensors="pt", truncation=True)




# tokenize pre-processed 22

tokenizer_22 = load_tokenizer()
tokenized_text22 = tokenizer_22(text_content22[:512], return_tensors="pt", truncation=True)



# tokenize pre-processed 23

tokenizer_23 = load_tokenizer()
tokenized_text23 = tokenizer_23(text_content23[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 24

tokenizer_24 = load_tokenizer()
tokenized_text24 = tokenizer_24(text_content24[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 25

tokenizer_25 = load_tokenizer()
tokenized_text25 = tokenizer_25(text_content25[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 26

tokenizer_26 = load_tokenizer()
tokenized_text26 = tokenizer_26(text_content26[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 27

tokenizer_27 = load_tokenizer()
tokenized_text27 = tokenizer_27(text_content27[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 28

tokenizer_28 = load_tokenizer()
tokenized_text28 = tokenizer_28(text_content28[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 29

tokenizer_29 = load_tokenizer()
tokenized_text29 = tokenizer_29(text_content29[:512], return_tensors="pt", truncation=True)



# tokenize pre-processed 30

tokenizer_30 = load_tokenizer()
tokenized_text30 = tokenizer_30(text_content30[:512], return_tensors="pt", truncation=True)



# tokenize pre-processed 31

tokenizer_31 = load_tokenizer()
tokenized_text31 = tokenizer_31(text_content31[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 32

tokenizer_32 = load_tokenizer()
tokenized_text32 = tokenizer_32(text_content32[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 33

tokenizer_33 = load_tokenizer()
tokenized_text33 = tokenizer_33(text_content33[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 34

tokenizer_34 = load_tokenizer()
tokenized_text34 = tokenizer_34(text_content34[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 35

tokenizer_35 = load_tokenizer()
tokenized_text35 = tokenizer_35(text_content35[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 36

tokenizer_36 = load_tokenizer()
tokenized_text36 = tokenizer_36(text_content36[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 37

tokenizer_37 = load_tokenizer()
tokenized_text37 = tokenizer_37(text_content37[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 38

tokenizer_38 = load_tokenizer()
tokenized_text38 = tokenizer_38(text_content38[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 39

tokenizer_39 = load_tokenizer()
tokenized_text39 = tokenizer_39(text_content39[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 40

tokenizer_40 = load_tokenizer()
tokenized_text40 = tokenizer_40(text_content40[:512], return_tensors="pt", truncation=True)



# tokenize pre-processed 41

tokenizer_41 = load_tokenizer()
tokenized_text41 = tokenizer_41(text_content41[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 42

tokenizer_42 = load_tokenizer()
tokenized_text42 = tokenizer_42(text_content42[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 43

tokenizer_43 = load_tokenizer()
tokenized_text43 = tokenizer_43(text_content43[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 44

tokenizer_44 = load_tokenizer()
tokenized_text44 = tokenizer_44(text_content44[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 45

tokenizer_45 = load_tokenizer()
tokenized_text45 = tokenizer_45(text_content45[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 46

tokenizer_46 = load_tokenizer()
tokenized_text46 = tokenizer_46(text_content46[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 47

tokenizer_47 = load_tokenizer()
tokenized_text47 = tokenizer_47(text_content47[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 48

tokenizer_48 = load_tokenizer()
tokenized_text48 = tokenizer_48(text_content48[:512], return_tensors="pt", truncation=True)


# tokenize pre-processed 49

tokenizer_49 = load_tokenizer()
tokenized_text49 = tokenizer_49(text_content49[:512], return_tensors="pt", truncation=True)

# %% [markdown]
# ## SDG LIST

# %%
# SDG labels list
label_list = [
    'GOAL 1: No Poverty',
    'GOAL 2: Zero Hunger',
    'GOAL 3: Good Health and Well-being',
    'GOAL 4: Quality Education',
    'GOAL 5: Gender Equality',
    'GOAL 6: Clean Water and Sanitation',
    'GOAL 7: Affordable and Clean Energy',
    'GOAL 8: Decent Work and Economic Growth',
    'GOAL 9: Industry, Innovation and Infrastructure',
    'GOAL 10: Reduced Inequality',
    'GOAL 11: Sustainable Cities and Communities',
    'GOAL 12: Responsible Consumption and Production',
    'GOAL 13: Climate Action',
    'GOAL 14: Life Below Water',
    'GOAL 15: Life on Land',
    'GOAL 16: Peace, Justice and Strong Institutions'
]

# %% [markdown]
# ## The model

# %%
# Predict text for 1
model = load_model()

# Predict text for 2
model2 = load_model()

# # Predict text for 3
model3 = load_model()

# Predict text for 4
model4 = load_model()

# Predict text for 5
model5 = load_model()

# Predict text for 6
model6 = load_model()

# Predict text for 7
model7 = load_model()

# Predict text for 8
model8 = load_model()

# Predict text for 9
model9 = load_model()

# Predict text for 10
model10 = load_model()

# Predict text for 11
model11 = load_model()

# Predict text for 12
model12 = load_model()

# Predict text for 13
model13 = load_model()

# Predict text for 14
model14 = load_model()

# Predict text for 15
model15 = load_model()

# Predict text for 16
model16 = load_model()

# Predict text for 17
model17 = load_model()

# Predict text for 18
model18 = load_model()

# Predict text for 19
model19 = load_model()

# Predict text for 20
model20 = load_model()

# Predict text for 21
model21 = load_model()

# Predict text for 22
model22 = load_model()

# Predict text for 23
model23 = load_model()

# Predict text for 24
model24 = load_model()

# Predict text for 25
model25 = load_model()

# Predict text for 26
model26 = load_model()

# Predict text for 27
model27 = load_model()

# Predict text for 28
model28 = load_model()

# Predict text for 29
model29 = load_model()

# Predict text for 30
model30 = load_model()

# Predict text for 31
model31 = load_model()

# Predict text for 32
model32 = load_model()


# Predict text for 33
model33 = load_model()


# Predict text for 34
model34 = load_model()

# Predict text for 35
model35 = load_model()

# Predict text for 36
model36 = load_model()

# Predict text for 37
model37 = load_model()

# Predict text for 38
model38 = load_model()

# Predict text for 39
model39 = load_model()

# Predict text for 40
model40 = load_model()

# Predict text for 41
model41 = load_model()

# Predict text for 42
model42 = load_model()

# Predict text for 43
model43 = load_model()

# Predict text for 44
model44 = load_model()

# Predict text for 45
model45 = load_model()

# Predict text for 46
model46 = load_model()

# Predict text for 47
model47 = load_model()

# Predict text for 48
model48 = load_model()

# Predict text for 49
model49 = load_model()

# %%
# Predict text for 1
text_logits = model(**tokenized_text).logits
predictions = torch.softmax(text_logits, dim=1).tolist()[0]
predictions = [round(a, 3) for a in predictions]



# Predict text for 2
text_logits2 = model2(**tokenized_text2).logits
predictions2 = torch.softmax(text_logits2, dim=1).tolist()[0]
predictions2 = [round(a, 3) for a in predictions2]


# Predict text for 3

text_logits3 = model3(**tokenized_text3).logits
predictions3 = torch.softmax(text_logits3, dim=1).tolist()[0]
predictions3 = [round(a, 3) for a in predictions3]



# Predict text for 4
text_logits4 = model4(**tokenized_text4).logits
predictions4 = torch.softmax(text_logits4, dim=1).tolist()[0]
predictions4 = [round(a, 3) for a in predictions4]



# Predict text for 5
text_logits5 = model5(**tokenized_text5).logits
predictions5 = torch.softmax(text_logits5, dim=1).tolist()[0]
predictions5 = [round(a, 3) for a in predictions5]




# Predict text for 6
text_logits6 = model6(**tokenized_text6).logits
predictions6 = torch.softmax(text_logits6, dim=1).tolist()[0]
predictions6 = [round(a, 3) for a in predictions6]



# Predict text for 7
text_logits7 = model7(**tokenized_text7).logits
predictions7 = torch.softmax(text_logits7, dim=1).tolist()[0]
predictions7 = [round(a, 3) for a in predictions7]



# Predict text for 8
text_logits8 = model8(**tokenized_text8).logits
predictions8 = torch.softmax(text_logits8, dim=1).tolist()[0]
predictions8 = [round(a, 3) for a in predictions8]




# Predict text for 9
text_logits9 = model9(**tokenized_text9).logits
predictions9 = torch.softmax(text_logits9, dim=1).tolist()[0]
predictions9 = [round(a, 3) for a in predictions9]




# Predict text for 10
text_logits10 = model10(**tokenized_text10).logits
predictions10 = torch.softmax(text_logits10, dim=1).tolist()[0]
predictions10 = [round(a, 3) for a in predictions10]


# Predict text for 11
text_logits11 = model11(**tokenized_text11).logits
predictions11 = torch.softmax(text_logits11, dim=1).tolist()[0]
predictions11 = [round(a, 3) for a in predictions11]




# Predict text for 12
text_logits12 = model12(**tokenized_text12).logits
predictions12 = torch.softmax(text_logits12, dim=1).tolist()[0]
predictions12 = [round(a, 3) for a in predictions12]




# Predict text for 13
text_logits13 = model13(**tokenized_text13).logits
predictions13 = torch.softmax(text_logits13, dim=1).tolist()[0]
predictions13 = [round(a, 3) for a in predictions13]




# Predict text for 14
text_logits14 = model14(**tokenized_text14).logits
predictions14 = torch.softmax(text_logits14, dim=1).tolist()[0]
predictions14 = [round(a, 3) for a in predictions14]




# Predict text for 15
text_logits15 = model14(**tokenized_text15).logits
predictions15 = torch.softmax(text_logits15, dim=1).tolist()[0]
predictions15 = [round(a, 3) for a in predictions15]




# Predict text for 16
text_logits16 = model16(**tokenized_text16).logits
predictions16 = torch.softmax(text_logits16, dim=1).tolist()[0]
predictions16 = [round(a, 3) for a in predictions16]



# Predict text for 17
text_logits17 = model17(**tokenized_text17).logits
predictions17 = torch.softmax(text_logits17, dim=1).tolist()[0]
predictions17 = [round(a, 3) for a in predictions17]



# Predict text for 18
text_logits18 = model18(**tokenized_text18).logits
predictions18 = torch.softmax(text_logits18, dim=1).tolist()[0]
predictions18 = [round(a, 3) for a in predictions18]


# Predict text for 19

text_logits19 = model19(**tokenized_text19).logits
predictions19 = torch.softmax(text_logits19, dim=1).tolist()[0]
predictions19 = [round(a, 3) for a in predictions19]



# Predict text for 20
text_logits20 = model20(**tokenized_text20).logits
predictions20 = torch.softmax(text_logits20, dim=1).tolist()[0]
predictions20 = [round(a, 3) for a in predictions20]



# Predict text for 21
text_logits21 = model21(**tokenized_text21).logits
predictions21 = torch.softmax(text_logits21, dim=1).tolist()[0]
predictions21 = [round(a, 3) for a in predictions21]




# Predict text for 22
text_logits22 = model22(**tokenized_text22).logits
predictions22 = torch.softmax(text_logits22, dim=1).tolist()[0]
predictions22 = [round(a, 3) for a in predictions22]



# Predict text for 23
text_logits23 = model23(**tokenized_text23).logits
predictions23 = torch.softmax(text_logits23, dim=1).tolist()[0]
predictions23 = [round(a, 3) for a in predictions23]



# Predict text for 24
text_logits24 = model24(**tokenized_text24).logits
predictions24 = torch.softmax(text_logits24, dim=1).tolist()[0]
predictions24 = [round(a, 3) for a in predictions24]




# Predict text for 25
text_logits25 = model25(**tokenized_text25).logits
predictions25 = torch.softmax(text_logits25, dim=1).tolist()[0]
predictions25 = [round(a, 3) for a in predictions25]




# Predict text for 26
text_logits26 = model26(**tokenized_text26).logits
predictions26 = torch.softmax(text_logits26, dim=1).tolist()[0]
predictions26 = [round(a, 3) for a in predictions26]


# Predict text for 27
text_logits27 = model27(**tokenized_text27).logits
predictions27 = torch.softmax(text_logits27, dim=1).tolist()[0]
predictions27 = [round(a, 3) for a in predictions27]




# Predict text for 28
text_logits28 = model28(**tokenized_text28).logits
predictions28 = torch.softmax(text_logits28, dim=1).tolist()[0]
predictions28 = [round(a, 3) for a in predictions28]




# Predict text for 29
text_logits29 = model29(**tokenized_text29).logits
predictions29 = torch.softmax(text_logits29, dim=1).tolist()[0]
predictions29 = [round(a, 3) for a in predictions29]




# Predict text for 30
text_logits30 = model30(**tokenized_text30).logits
predictions30 = torch.softmax(text_logits30, dim=1).tolist()[0]
predictions30 = [round(a, 3) for a in predictions30]


# Predict text for 31
text_logits31 = model31(**tokenized_text31).logits
predictions31 = torch.softmax(text_logits31, dim=1).tolist()[0]
predictions31 = [round(a, 3) for a in predictions31]


# Predict text for 32
text_logits32 = model31(**tokenized_text32).logits
predictions32 = torch.softmax(text_logits32, dim=1).tolist()[0]
predictions32 = [round(a, 3) for a in predictions32]

# %%
# Predict text for 33
text_logits33 = model33(**tokenized_text33).logits
predictions33 = torch.softmax(text_logits33, dim=1).tolist()[0]
predictions33 = [round(a, 3) for a in predictions33]


# Predict text for 34
text_logits34 = model34(**tokenized_text34).logits
predictions34 = torch.softmax(text_logits34, dim=1).tolist()[0]
predictions34 = [round(a, 3) for a in predictions34]


# Predict text for 35
text_logits35 = model35(**tokenized_text35).logits
predictions35 = torch.softmax(text_logits35, dim=1).tolist()[0]
predictions35 = [round(a, 3) for a in predictions35]


# Predict text for 36
text_logits36 = model36(**tokenized_text36).logits
predictions36 = torch.softmax(text_logits36, dim=1).tolist()[0]
predictions36 = [round(a, 3) for a in predictions36]


# Predict text for 37
text_logits37 = model37(**tokenized_text37).logits
predictions37 = torch.softmax(text_logits37, dim=1).tolist()[0]
predictions37 = [round(a, 3) for a in predictions37]


# Predict text for 38
text_logits38 = model38(**tokenized_text38).logits
predictions38 = torch.softmax(text_logits38, dim=1).tolist()[0]
predictions38 = [round(a, 3) for a in predictions38]


# Predict text for 39
text_logits39 = model39(**tokenized_text39).logits
predictions39 = torch.softmax(text_logits39, dim=1).tolist()[0]
predictions39 = [round(a, 3) for a in predictions39]


# Predict text for 40
text_logits40 = model40(**tokenized_text40).logits
predictions40 = torch.softmax(text_logits40, dim=1).tolist()[0]
predictions40 = [round(a, 3) for a in predictions40]


# Predict text for 41
text_logits41 = model41(**tokenized_text41).logits
predictions41 = torch.softmax(text_logits41, dim=1).tolist()[0]
predictions41 = [round(a, 3) for a in predictions41]


# Predict text for 42
text_logits42 = model42(**tokenized_text42).logits
predictions42 = torch.softmax(text_logits32, dim=1).tolist()[0]
predictions42 = [round(a, 3) for a in predictions42]


# Predict text for 43
text_logits43 = model43(**tokenized_text43).logits
predictions43 = torch.softmax(text_logits43, dim=1).tolist()[0]
predictions43 = [round(a, 3) for a in predictions43]


# Predict text for 44
text_logits44 = model44(**tokenized_text44).logits
predictions44 = torch.softmax(text_logits44, dim=1).tolist()[0]
predictions44 = [round(a, 3) for a in predictions44]


# Predict text for 45
text_logits45 = model45(**tokenized_text45).logits
predictions45 = torch.softmax(text_logits45, dim=1).tolist()[0]
predictions45 = [round(a, 3) for a in predictions45]


# Predict text for 46
text_logits46 = model46(**tokenized_text46).logits
predictions46 = torch.softmax(text_logits46, dim=1).tolist()[0]
predictions46 = [round(a, 3) for a in predictions46]


# Predict text for 47
text_logits47 = model47(**tokenized_text47).logits
predictions47 = torch.softmax(text_logits47, dim=1).tolist()[0]
predictions47 = [round(a, 3) for a in predictions47]


# Predict text for 48
text_logits48 = model48(**tokenized_text48).logits
predictions48 = torch.softmax(text_logits48, dim=1).tolist()[0]
predictions48 = [round(a, 3) for a in predictions48]


# Predict text for 49
text_logits49 = model49(**tokenized_text49).logits
predictions49 = torch.softmax(text_logits49, dim=1).tolist()[0]
predictions49 = [round(a, 3) for a in predictions49]

# %%
# Dictionary with label as key and percentage as value
pred_dict = (dict(zip(label_list, predictions)))
pred_dict2 = (dict(zip(label_list, predictions2)))
pred_dict3 = (dict(zip(label_list, predictions3)))
pred_dict4 = (dict(zip(label_list, predictions4)))


pred_dict5 = (dict(zip(label_list, predictions5)))
pred_dict6 = (dict(zip(label_list, predictions6)))
pred_dict7 = (dict(zip(label_list, predictions7)))
pred_dict8 = (dict(zip(label_list, predictions8)))
pred_dict9 = (dict(zip(label_list, predictions9)))
pred_dict10 = (dict(zip(label_list, predictions10)))
pred_dict11 = (dict(zip(label_list, predictions11)))
pred_dict12 = (dict(zip(label_list, predictions12)))
pred_dict13 = (dict(zip(label_list, predictions13)))
pred_dict14 = (dict(zip(label_list, predictions14)))
pred_dict15 = (dict(zip(label_list, predictions15)))
pred_dict16 = (dict(zip(label_list, predictions16)))



pred_dict17 = (dict(zip(label_list, predictions17)))
pred_dict18 = (dict(zip(label_list, predictions18)))
pred_dict19 = (dict(zip(label_list, predictions19)))
pred_dict20 = (dict(zip(label_list, predictions20)))
pred_dict21 = (dict(zip(label_list, predictions21)))
pred_dict22 = (dict(zip(label_list, predictions22)))
pred_dict23 = (dict(zip(label_list, predictions23)))
pred_dict24 = (dict(zip(label_list, predictions24)))
pred_dict25 = (dict(zip(label_list, predictions25)))
pred_dict26 = (dict(zip(label_list, predictions26)))
pred_dict27 = (dict(zip(label_list, predictions27)))
pred_dict28 = (dict(zip(label_list, predictions28)))



pred_dict29 = (dict(zip(label_list, predictions29)))
pred_dict30 = (dict(zip(label_list, predictions30)))
pred_dict31 = (dict(zip(label_list, predictions31)))
pred_dict32 = (dict(zip(label_list, predictions32)))
pred_dict33 = (dict(zip(label_list, predictions33)))
pred_dict34 = (dict(zip(label_list, predictions34)))
pred_dict35 = (dict(zip(label_list, predictions35)))
pred_dict36 = (dict(zip(label_list, predictions36)))
pred_dict37 = (dict(zip(label_list, predictions37)))
pred_dict38 = (dict(zip(label_list, predictions38)))
pred_dict39 = (dict(zip(label_list, predictions39)))
pred_dict40 = (dict(zip(label_list, predictions40)))


pred_dict41 = (dict(zip(label_list, predictions41)))
pred_dict42 = (dict(zip(label_list, predictions42)))
pred_dict43 = (dict(zip(label_list, predictions43)))
pred_dict44 = (dict(zip(label_list, predictions44)))
pred_dict45 = (dict(zip(label_list, predictions45)))
pred_dict46 = (dict(zip(label_list, predictions46)))
pred_dict47 = (dict(zip(label_list, predictions47)))
pred_dict48 = (dict(zip(label_list, predictions48)))
pred_dict49 = (dict(zip(label_list, predictions49)))

# %%
# Print predictions in the notebook
# display(Markdown("##### Prediction outcome"))
# display(Markdown(""))

# Display predictions as a DataFrame
df1 = pd.DataFrame(pred_dict.items(), columns=["SDG COMPONENTS", "Likelihood"])
df2 = pd.DataFrame(pred_dict2.items(), columns=["SDG COMPONENTS", "Likelihood"])
df3 = pd.DataFrame(pred_dict3.items(), columns=["SDG COMPONENTS", "Likelihood"])
df4 = pd.DataFrame(pred_dict4.items(), columns=["SDG COMPONENTS", "Likelihood"])
df5 = pd.DataFrame(pred_dict5.items(), columns=["SDG COMPONENTS", "Likelihood"])
df6 = pd.DataFrame(pred_dict6.items(), columns=["SDG COMPONENTS", "Likelihood"])
df7 = pd.DataFrame(pred_dict7.items(), columns=["SDG COMPONENTS", "Likelihood"])
df8 = pd.DataFrame(pred_dict8.items(), columns=["SDG COMPONENTS", "Likelihood"])
df9 = pd.DataFrame(pred_dict9.items(), columns=["SDG COMPONENTS", "Likelihood"])
df10 = pd.DataFrame(pred_dict10.items(), columns=["SDG COMPONENTS", "Likelihood"])
df11 = pd.DataFrame(pred_dict11.items(), columns=["SDG COMPONENTS", "Likelihood"])
df12 = pd.DataFrame(pred_dict12.items(), columns=["SDG COMPONENTS", "Likelihood"])
df13 = pd.DataFrame(pred_dict13.items(), columns=["SDG COMPONENTS", "Likelihood"])
df14 = pd.DataFrame(pred_dict14.items(), columns=["SDG COMPONENTS", "Likelihood"])
df15 = pd.DataFrame(pred_dict15.items(), columns=["SDG COMPONENTS", "Likelihood"])
df16 = pd.DataFrame(pred_dict16.items(), columns=["SDG COMPONENTS", "Likelihood"])
df17 = pd.DataFrame(pred_dict17.items(), columns=["SDG COMPONENTS", "Likelihood"])
df18 = pd.DataFrame(pred_dict18.items(), columns=["SDG COMPONENTS", "Likelihood"])
df19 = pd.DataFrame(pred_dict19.items(), columns=["SDG COMPONENTS", "Likelihood"])
df20 = pd.DataFrame(pred_dict20.items(), columns=["SDG COMPONENTS", "Likelihood"])
df21 = pd.DataFrame(pred_dict21.items(), columns=["SDG COMPONENTS", "Likelihood"])
df22 = pd.DataFrame(pred_dict22.items(), columns=["SDG COMPONENTS", "Likelihood"])
df23 = pd.DataFrame(pred_dict23.items(), columns=["SDG COMPONENTS", "Likelihood"])
df24 = pd.DataFrame(pred_dict24.items(), columns=["SDG COMPONENTS", "Likelihood"])
df25 = pd.DataFrame(pred_dict25.items(), columns=["SDG COMPONENTS", "Likelihood"])
df26 = pd.DataFrame(pred_dict26.items(), columns=["SDG COMPONENTS", "Likelihood"])
df27 = pd.DataFrame(pred_dict27.items(), columns=["SDG COMPONENTS", "Likelihood"])
df28 = pd.DataFrame(pred_dict28.items(), columns=["SDG COMPONENTS", "Likelihood"])
df29 = pd.DataFrame(pred_dict29.items(), columns=["SDG COMPONENTS", "Likelihood"])
df30 = pd.DataFrame(pred_dict30.items(), columns=["SDG COMPONENTS", "Likelihood"])
df31 = pd.DataFrame(pred_dict31.items(), columns=["SDG COMPONENTS", "Likelihood"])
df32 = pd.DataFrame(pred_dict32.items(), columns=["SDG COMPONENTS", "Likelihood"])
df33 = pd.DataFrame(pred_dict33.items(), columns=["SDG COMPONENTS", "Likelihood"])
df34 = pd.DataFrame(pred_dict34.items(), columns=["SDG COMPONENTS", "Likelihood"])
df35 = pd.DataFrame(pred_dict35.items(), columns=["SDG COMPONENTS", "Likelihood"])
df36 = pd.DataFrame(pred_dict36.items(), columns=["SDG COMPONENTS", "Likelihood"])
df37 = pd.DataFrame(pred_dict37.items(), columns=["SDG COMPONENTS", "Likelihood"])
df38 = pd.DataFrame(pred_dict38.items(), columns=["SDG COMPONENTS", "Likelihood"])
df39 = pd.DataFrame(pred_dict39.items(), columns=["SDG COMPONENTS", "Likelihood"])
df40 = pd.DataFrame(pred_dict40.items(), columns=["SDG COMPONENTS", "Likelihood"])
df41 = pd.DataFrame(pred_dict41.items(), columns=["SDG COMPONENTS", "Likelihood"])
df42 = pd.DataFrame(pred_dict42.items(), columns=["SDG COMPONENTS", "Likelihood"])
df43 = pd.DataFrame(pred_dict43.items(), columns=["SDG COMPONENTS", "Likelihood"])
df44 = pd.DataFrame(pred_dict44.items(), columns=["SDG COMPONENTS", "Likelihood"])
df45 = pd.DataFrame(pred_dict45.items(), columns=["SDG COMPONENTS", "Likelihood"])
df46 = pd.DataFrame(pred_dict46.items(), columns=["SDG COMPONENTS", "Likelihood"])
df47 = pd.DataFrame(pred_dict47.items(), columns=["SDG COMPONENTS", "Likelihood"])
df48 = pd.DataFrame(pred_dict48.items(), columns=["SDG COMPONENTS", "Likelihood"])
df49 = pd.DataFrame(pred_dict49.items(), columns=["SDG COMPONENTS", "Likelihood"])

# %%
# Concatenate the dataframes along the columns axis
combined_df = pd.concat([df1.set_index('SDG COMPONENTS'),
                         df2.set_index('SDG COMPONENTS'),
                         df3.set_index('SDG COMPONENTS'),
                         df4.set_index('SDG COMPONENTS'),

                         df5.set_index('SDG COMPONENTS'),
                         df6.set_index('SDG COMPONENTS'),
                         df7.set_index('SDG COMPONENTS'),
                         df8.set_index('SDG COMPONENTS'),
                         df9.set_index('SDG COMPONENTS'),
                         df10.set_index('SDG COMPONENTS'),
                         df11.set_index('SDG COMPONENTS'),
                         df12.set_index('SDG COMPONENTS'),
                         df13.set_index('SDG COMPONENTS'),
                         df14.set_index('SDG COMPONENTS'),
                         df15.set_index('SDG COMPONENTS'),
                         df16.set_index('SDG COMPONENTS'),


                         df17.set_index('SDG COMPONENTS'),
                         df18.set_index('SDG COMPONENTS'),
                         df19.set_index('SDG COMPONENTS'),
                         df20.set_index('SDG COMPONENTS'),
                         df21.set_index('SDG COMPONENTS'),
                         df22.set_index('SDG COMPONENTS'),
                         df23.set_index('SDG COMPONENTS'),
                         df24.set_index('SDG COMPONENTS'),
                         df25.set_index('SDG COMPONENTS'),
                         df26.set_index('SDG COMPONENTS'),
                         df27.set_index('SDG COMPONENTS'),


                         df28.set_index('SDG COMPONENTS'),
                         df29.set_index('SDG COMPONENTS'),
                         df30.set_index('SDG COMPONENTS'),
                         df31.set_index('SDG COMPONENTS'),
                         df32.set_index('SDG COMPONENTS'),
                         df33.set_index('SDG COMPONENTS'),
                         df34.set_index('SDG COMPONENTS'),
                         df35.set_index('SDG COMPONENTS'),
                         df36.set_index('SDG COMPONENTS'),
                         df37.set_index('SDG COMPONENTS'),

                        df38.set_index('SDG COMPONENTS'),
                         df39.set_index('SDG COMPONENTS'),
                         df40.set_index('SDG COMPONENTS'),
                         df41.set_index('SDG COMPONENTS'),
                         df42.set_index('SDG COMPONENTS'),
                         df43.set_index('SDG COMPONENTS'),
                         df44.set_index('SDG COMPONENTS'),
                         df45.set_index('SDG COMPONENTS'),
                         df46.set_index('SDG COMPONENTS'),
                         df47.set_index('SDG COMPONENTS'),
                         df48.set_index('SDG COMPONENTS'),
                         df49.set_index('SDG COMPONENTS')
                         ], axis=1, keys=['ComPany 1',
                                          'ComPany 2',
                                          'ComPany 3',
                                          'ComPany 4',
                                          'ComPany 5',
                                          'ComPany 6',
                                          'ComPany 7',
                                          'ComPany 8',
                                          'ComPany 9',
                                          'ComPany 10',
                                          'ComPany 11',
                                          'ComPany 12',
                                          'ComPany 13',
                                          'ComPany 14',
                                          'ComPany 15',
                                          'ComPany 16',
                                          'ComPany 17',
                                          'ComPany 18',
                                          'ComPany 19',
                                          'ComPany 20',
                                          'ComPany 21',
                                          'ComPany 22',
                                          'ComPany 23',
                                          'ComPany 24',
                                          'ComPany 25',
                                          'ComPany 26',
                                          'ComPany 27',
                                          'ComPany 28',
                                          'ComPany 29',
                                          'ComPany 30',
                                          'ComPany 31',
                                          'ComPany 32',
                                          'ComPany 33',
                                          'ComPany 34',
                                          'ComPany 35',
                                          'ComPany 36',
                                          'ComPany 37',
                                          'ComPany 38',
                                          'ComPany 39',
                                          'ComPany 40',
                                          'ComPany 41',
                                          'ComPany 42',
                                          'ComPany 43',
                                          'ComPany 44',
                                          'ComPany 45',
                                          'ComPany 46',
                                          'ComPany 47',
                                          'ComPany 48',
                                          'ComPany 49'
                                          ])

# %% [markdown]
# ## Result Analysis

# %% [markdown]
# ## 1. Affinity of the companies with the different SDG Components

# %%
# display(combined_df)

# %%
# Create a function to return the color corresponding to the SDG with the highest probability
def color_func(value):
    max_index = np.argmax(value)
    # colors = ['red', 'green', 'blue', 'yellow', 'orange', 'purple', 'cyan', 'magenta', 'gray', 'brown', 'pink', 'olive', 'lightblue', 'lime', 'teal', 'navy']
    colors = [
    'red', 'green', 'blue', 'yellow', 'magenta', 'cyan', 'maroon', 'lime', 'navy', 'olive',
    'purple', 'teal', 'orange', 'pink', 'black', 'white', 'gray', 'red', 'green', 'blue',
    'yellow', 'magenta', 'cyan', 'maroon', 'lime', 'navy', 'olive', 'purple', 'teal',
    'orange', 'pink', 'black', 'white', 'gray', 'red', 'green', 'blue', 'yellow',
    'magenta', 'cyan', 'maroon', 'lime', 'navy', 'olive', 'purple', 'teal', 'orange',
    'pink', 'black', 'white', 'gray']

    return 'color: %s' % colors[max_index]

# Create the heatmap with the custom coloring
heatmap = (combined_df*100).style.applymap(color_func).format("{:.2f}")

# Define the title label
title_label = "Probability of the different SDG Text Files with the 20 Company Files"

# Wrap the heatmap in an HTML table with border lines and a title label
html = f'<table style="border: 1px solid black;">' \
       f'<caption style="text-align: center; font-weight: bold; font-size: large;">{title_label}</caption>' \
       f'<tr><td>{heatmap.to_html()}</td></tr>' \
       f'</table>'  # Adjust the max-width and other styles as needed

# Display the heatmap within a table with a title label
display(HTML(html))
# Out:
# <table style="border: 1px solid black;"><caption style="text-align: center; font-weight: bold; font-size: large;">Probability of the different SDG Text Files with the 20 Company Files</caption><tr><td><style type="text/css">
# #T_43cbc_row0_col0, #T_43cbc_row0_col1, #T_43cbc_row0_col2, #T_43cbc_row0_col3, #T_43cbc_row0_col4, #T_43cbc_row0_col5, #T_43cbc_row0_col6, #T_43cbc_row0_col7, #T_43cbc_row0_col8, #T_43cbc_row0_col9, #T_43cbc_row0_col10, #T_43cbc_row0_col11, #T_43cbc_row0_col12, #T_43cbc_row0_col13, #T_43cbc_row0_col14, #T_43cbc_row0_col15, #T_43cbc_row0_col16, #T_43cbc_row0_col17, #T_43cbc_row0_col18, #T_43cbc_row0_col19, #T_43cbc_row0_col20, #T_43cbc_row0_col21, #T_43cbc_row0_col22, #T_43cbc_row0_col23, #T_43cbc_row0_col24, #T_43cbc_row0_col25, #T_43cbc_row0_col26, #T_43cbc_row0_col27, #T_43cbc_row0_col28, #T_43cbc_row0_col29, #T_43cbc_row0_col30, #T_43cbc_row0_col31, #T_43cbc_row0_col32, #T_43cbc_row0_col33, #T_43cbc_row0_col34, #T_43cbc_row0_col35, #T_43cbc_row0_col36, #T_43cbc_row0_col37, #T_43cbc_row0_col38, #T_43cbc_row0_col39, #T_43cbc_row0_col40, #T_43cbc_row0_col41, #T_43cbc_row0_col42, #T_43cbc_row0_col43, #T_43cbc_row0_col44, #T_43cbc_row0_col45, #T_43cbc_row0_col46, #T_43cbc_row0_col47, #T_43cbc_row0_col48, #T_43cbc_row1_col0, #T_43cbc_row1_col1, #T_43cbc_row1_col2, #T_43cbc_row1_col3, #T_43cbc_row1_col4, #T_43cbc_row1_col5, #T_43cbc_row1_col6, #T_43cbc_row1_col7, #T_43cbc_row1_col8, #T_43cbc_row1_col9, #T_43cbc_row1_col10, #T_43cbc_row1_col11, #T_43cbc_row1_col12, #T_43cbc_row1_col13, #T_43cbc_row1_col14, #T_43cbc_row1_col15, #T_43cbc_row1_col16, #T_43cbc_row1_col17, #T_43cbc_row1_col18, #T_43cbc_row1_col19, #T_43cbc_row1_col20, #T_43cbc_row1_col21, #T_43cbc_row1_col22, #T_43cbc_row1_col23, #T_43cbc_row1_col24, #T_43cbc_row1_col25, #T_43cbc_row1_col26, #T_43cbc_row1_col27, #T_43cbc_row1_col28, #T_43cbc_row1_col29, #T_43cbc_row1_col30, #T_43cbc_row1_col31, #T_43cbc_row1_col32, #T_43cbc_row1_col33, #T_43cbc_row1_col34, #T_43cbc_row1_col35, #T_43cbc_row1_col36, #T_43cbc_row1_col37, #T_43cbc_row1_col38, #T_43cbc_row1_col39, #T_43cbc_row1_col40, #T_43cbc_row1_col41, #T_43cbc_row1_col42, #T_43cbc_row1_col43, #T_43cbc_row1_col44, #T_43cbc_row1_col45, #T_43cbc_row1_col46, #T_43cbc_row1_col47, #T_43cbc_row1_col48, #T_43cbc_row2_col0, #T_43cbc_row2_col1, #T_43cbc_row2_col2, #T_43cbc_row2_col3, #T_43cbc_row2_col4, #T_43cbc_row2_col5, #T_43cbc_row2_col6, #T_43cbc_row2_col7, #T_43cbc_row2_col8, #T_43cbc_row2_col9, #T_43cbc_row2_col10, #T_43cbc_row2_col11, #T_43cbc_row2_col12, #T_43cbc_row2_col13, #T_43cbc_row2_col14, #T_43cbc_row2_col15, #T_43cbc_row2_col16, #T_43cbc_row2_col17, #T_43cbc_row2_col18, #T_43cbc_row2_col19, #T_43cbc_row2_col20, #T_43cbc_row2_col21, #T_43cbc_row2_col22, #T_43cbc_row2_col23, #T_43cbc_row2_col24, #T_43cbc_row2_col25, #T_43cbc_row2_col26, #T_43cbc_row2_col27, #T_43cbc_row2_col28, #T_43cbc_row2_col29, #T_43cbc_row2_col30, #T_43cbc_row2_col31, #T_43cbc_row2_col32, #T_43cbc_row2_col33, #T_43cbc_row2_col34, #T_43cbc_row2_col35, #T_43cbc_row2_col36, #T_43cbc_row2_col37, #T_43cbc_row2_col38, #T_43cbc_row2_col39, #T_43cbc_row2_col40, #T_43cbc_row2_col41, #T_43cbc_row2_col42, #T_43cbc_row2_col43, #T_43cbc_row2_col44, #T_43cbc_row2_col45, #T_43cbc_row2_col46, #T_43cbc_row2_col47, #T_43cbc_row2_col48, #T_43cbc_row3_col0, #T_43cbc_row3_col1, #T_43cbc_row3_col2, #T_43cbc_row3_col3, #T_43cbc_row3_col4, #T_43cbc_row3_col5, #T_43cbc_row3_col6, #T_43cbc_row3_col7, #T_43cbc_row3_col8, #T_43cbc_row3_col9, #T_43cbc_row3_col10, #T_43cbc_row3_col11, #T_43cbc_row3_col12, #T_43cbc_row3_col13, #T_43cbc_row3_col14, #T_43cbc_row3_col15, #T_43cbc_row3_col16, #T_43cbc_row3_col17, #T_43cbc_row3_col18, #T_43cbc_row3_col19, #T_43cbc_row3_col20, #T_43cbc_row3_col21, #T_43cbc_row3_col22, #T_43cbc_row3_col23, #T_43cbc_row3_col24, #T_43cbc_row3_col25, #T_43cbc_row3_col26, #T_43cbc_row3_col27, #T_43cbc_row3_col28, #T_43cbc_row3_col29, #T_43cbc_row3_col30, #T_43cbc_row3_col31, #T_43cbc_row3_col32, #T_43cbc_row3_col33, #T_43cbc_row3_col34, #T_43cbc_row3_col35, #T_43cbc_row3_col36, #T_43cbc_row3_col37, #T_43cbc_row3_col38, #T_43cbc_row3_col39, #T_43cbc_row3_col40, #T_43cbc_row3_col41, #T_43cbc_row3_col42, #T_43cbc_row3_col43, #T_43cbc_row3_col44, #T_43cbc ...

# %% [markdown]
# ## 2. Bar Plot

# %%
import altair as alt


# Reset the index of combined_df
combined_df_reset = combined_df.reset_index()

# Reshape the data to long format
df_long = combined_df_reset.melt(id_vars=['SDG COMPONENTS'], var_name='Company', value_name='Likelihood')

# Create the bar chart with specified width and height
chart = alt.Chart(df_long).mark_bar().encode(
    x=alt.X('Company', sort=None),
    y='Likelihood',
    color='SDG COMPONENTS'
).properties(
    width=800,  # Set width to 800 pixels
    height=600  # Set height to 600 pixels
)

# Display the chart
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## 3. Variation over time

# %%
# Increase the size of the plot
plt.figure(figsize=(10, 10))




# Plot the data
plt.plot(combined_df['ComPany 1'], label='ComPany 1')
plt.plot(combined_df['ComPany 2'], label='ComPany 2')
plt.plot(combined_df['ComPany 3'], label='ComPany 3')
plt.plot(combined_df['ComPany 4'], label='ComPany 4')
plt.plot(combined_df['ComPany 5'], label='ComPany 5')
plt.plot(combined_df['ComPany 6'], label='ComPany 6')
plt.plot(combined_df['ComPany 7'], label='ComPany 7')
plt.plot(combined_df['ComPany 8'], label='ComPany 8')
plt.plot(combined_df['ComPany 9'], label='ComPany 9')
plt.plot(combined_df['ComPany 10'], label='ComPany 10')
plt.plot(combined_df['ComPany 11'], label='ComPany 11')
plt.plot(combined_df['ComPany 12'], label='ComPany 12')
plt.plot(combined_df['ComPany 13'], label='ComPany 13')
plt.plot(combined_df['ComPany 14'], label='ComPany 14')
plt.plot(combined_df['ComPany 15'], label='ComPany 15')
plt.plot(combined_df['ComPany 16'], label='ComPany 16')
plt.plot(combined_df['ComPany 17'], label='ComPany 17')
plt.plot(combined_df['ComPany 18'], label='ComPany 18')
plt.plot(combined_df['ComPany 19'], label='ComPany 19')

plt.plot(combined_df['ComPany 20'], label='ComPany 20')
plt.plot(combined_df['ComPany 21'], label='ComPany 21')
plt.plot(combined_df['ComPany 22'], label='ComPany 22')
plt.plot(combined_df['ComPany 23'], label='ComPany 23')
plt.plot(combined_df['ComPany 24'], label='ComPany 24')
plt.plot(combined_df['ComPany 25'], label='ComPany 25')
plt.plot(combined_df['ComPany 26'], label='ComPany 26')
plt.plot(combined_df['ComPany 27'], label='ComPany 27')
plt.plot(combined_df['ComPany 28'], label='ComPany 28')
plt.plot(combined_df['ComPany 29'], label='ComPany 29')


plt.plot(combined_df['ComPany 30'], label='ComPany 30')
plt.plot(combined_df['ComPany 31'], label='ComPany 31')
plt.plot(combined_df['ComPany 32'], label='ComPany 32')
plt.plot(combined_df['ComPany 33'], label='ComPany 33')
plt.plot(combined_df['ComPany 34'], label='ComPany 34')
plt.plot(combined_df['ComPany 35'], label='ComPany 35')
plt.plot(combined_df['ComPany 36'], label='ComPany 36')
plt.plot(combined_df['ComPany 37'], label='ComPany 37')
plt.plot(combined_df['ComPany 39'], label='ComPany 38')
plt.plot(combined_df['ComPany 39'], label='ComPany 39')


plt.plot(combined_df['ComPany 40'], label='ComPany 40')
plt.plot(combined_df['ComPany 41'], label='ComPany 41')
plt.plot(combined_df['ComPany 42'], label='ComPany 42')
plt.plot(combined_df['ComPany 43'], label='ComPany 43')
plt.plot(combined_df['ComPany 44'], label='ComPany 44')
plt.plot(combined_df['ComPany 45'], label='ComPany 45')
plt.plot(combined_df['ComPany 46'], label='ComPany 46')
plt.plot(combined_df['ComPany 47'], label='ComPany 47')
plt.plot(combined_df['ComPany 48'], label='ComPany 48')
plt.plot(combined_df['ComPany 49'], label='ComPany 49')


plt.xlabel('Time')
plt.ylabel('Likelihood')
plt.title('Plot of Time Vs Likelihood of the SDG Components')

# Rotate x labels vertically
plt.xticks(rotation=90)

# Position the legend outside the plot on the right side
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %% [markdown]
# ## 4. Correlation

# %%
# Increase the size of the plot
plt.figure(figsize=(30, 30))

# Create the heatmap
sns.heatmap(combined_df[['ComPany 1',
                                          'ComPany 2',
                                          'ComPany 3',
                                          'ComPany 4',
                                          'ComPany 5',
                                          'ComPany 6',
                                          'ComPany 7',
                                          'ComPany 8',
                                          'ComPany 9',
                                          'ComPany 10',
                                          'ComPany 11',
                                          'ComPany 12',
                                          'ComPany 13',
                                          'ComPany 14',
                                          'ComPany 15',
                                          'ComPany 16',
                                          'ComPany 17',
                                          'ComPany 18',
                                          'ComPany 19',
                                          'ComPany 20',
                                          'ComPany 21',
                                          'ComPany 22',
                                          'ComPany 23',
                                          'ComPany 24',
                                          'ComPany 25',
                                          'ComPany 26',
                                          'ComPany 27',
                                          'ComPany 28',
                                          'ComPany 29',
                                          'ComPany 30',
                                          'ComPany 31',
                                          'ComPany 32',
                                          'ComPany 33',
                                          'ComPany 34',
                                          'ComPany 35',
                                          'ComPany 36',
                                          'ComPany 37',
                                          'ComPany 38',
                                          'ComPany 39',
                                          'ComPany 40',
                                          'ComPany 41',
                                          'ComPany 42',
                                          'ComPany 43',
                                          'ComPany 44',
                                          'ComPany 45',
                                          'ComPany 46',
                                          'ComPany 47',
                                          'ComPany 48',
                                          'ComPany 49'


                         ]].corr(), annot=True)

# Show the plot
plt.show()
